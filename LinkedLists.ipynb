# %% [markdown]
# # Linked List Intro

# %%
Linked Lists are diffent than regular lists. Linked lists do NOT have indexes like a regular list. The nodes in a linked list are spread out in memory. A variable called "head" points to the first node in the linked list and tail
points to the last node in the linked list. Each node within the list points to the next and the last one points to none.

# %% [markdown]
# # Appending a new node to the end of the list
#
# The last node points directly to the new node at the end and so does tail. This happens in 1 operation therefore it is O(1)

# %% [markdown]
# # Removing a node from the end of the list
#
# When we remove from the end of the linked list it is complicated. In order to have tail point to the last node, the tail pointer has to be set equal to another pointer that is pointing at the same node. So in order to get to that node we have to start at the head and iterate through the list until we get to that pointer. Then we can set tail equal to that pointer.
#
# Because we had to iterate through the entire list it is O(n)

# %% [markdown]
# # Adding an item to the front of the list.
#
# The new node sets equal to head. So the 4 points to the 11. There is only one operation so it is O(1)

# %% [markdown]
# # Removing the first node in the list
#
# Head just moves over to the next node. Resulting in 1 operation = O(1)

# %% [markdown]
# # Adding an item in the middle of the list
#
# We have to iterate through the list to connect the pointer of the new node. So it is O(n)

# %% [markdown]
# # Removing an item in the middle of the list
#
# Iterate through the list O(n)

# %% [markdown]
# # Lookup in a list
#
# O(n)

# %% [markdown]
# # Linked List Under the HOOD
#
# The node is not only the value, it is also the pointer. The node is essentially a dictionary.

# %%
head = {
    "value": 11,
    "next": {
        "value": 3,
        "next": {
            "value": 23,
            "next": {
                "value": 7,
                "next": None
            }
        }
    }
}

print(head['next']['next']['value'])

# %% [markdown]
# # Steps to writing a linked list
#
# ## Step 1. Stop thinking "linked list code", INSTEAD think "objects pointing to objects"
#
# Ask yourself, what is the smallest possible thing a linked list is made of?
#
# Answer: One node
# So the only place to start is the Node class/
#
# ## Step 2. How to derive the Node class from logic(Not memory)
#
# Ask yourself, what must every node know?
#
# Answer: It must store some data and it must know where the next nod is.
#
# So in english "when I create a node, I give it a calue and by default it points to nothing."
#
# ## Step 3. Where LinkedList exists at all
#
# The linkedlist obkect exists to answer 3 questions
# 1. Where does the list start?
# 2. Where does it end?
# 3. How many nodes are there?
#
# When I create a linked list, I must know the first node, the last node and the size
#
# Answer: head, tail, length
#
#
# ## Step 4. Deriving the LinkedList constructor
#
# Ask: What happens when a linked list is created?
#
# 1. Create one node
# 2. Set the head to that node
# 3. Set the tail to that node
# 4. Set the length to 1
